# %% [markdown]
# <a href="https://colab.research.google.com/github/KamathamBabySaritha/FMML_LAB_MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-20 13:04:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  62.1MB/s    in 1.1s
#
# 2024-04-20 13:05:01 (62.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2768   1711.04528v1  Neural networks have recently had a lot of suc...  stat
# 25963  1512.08212v2  We present techniques for improving performanc...    cs
# 28500  1706.08690v1  Face detection methods have relied on face dat...    cs
# 21937  1612.01490v3  Noise injection (NI) is an approach to mitigat...  stat
# 29814  1710.07198v1  This work proposes a system for retrieving clo...    cs
# ...             ...                                                ...   ...
# 22317  1601.01966v1  In this paper, a novel approach for coding nom...  stat
# 40848  1502.05534v1  Diagnosis of liver infection at preliminary st...    cs
# 21676   0909.0991v1  We present in this work a new family of kernel...  stat
# 22812  1707.05342v2  We study learning problems in the general setu...  stat
# 3375   1606.07575v1  Pruning of redundant or irrelevant instances o...  stat
#
#                                                    title  year  \
# 2768   Simple And Efficient Architecture Search for C...  2017
# 25963  Improving Facial Analysis and Performance Driv...  2015
# 28500  Large-scale Datasets: Faces with Partial Occlu...  2017
# 21937  Whiteout: Gaussian Adaptive Noise Regularizati...  2016
# 29814  Dress like a Star: Retrieving Fashion Products...  2017
# ...                                                  ...   ...
# 22317                   Numerical Coding of Nominal Data  2016
# 40848  NeuroSVM: A Graphical User Interface for Ident...  2015
# 21676  Kernels for Measures Defined on the Gram Matri...  2009
# 22812         An optimal unrestricted learning procedure  2017
# 3375   Multipartite Ranking-Selection of Low-Dimensio...  2016
#
#                                                 keywords
# 2768   [architectures, typically, cumbersome, automat...
# 25963  [techniques, improving, performance, animation...
# 28500  [detection, constrained, unconstrained, enviro...
# 21937  [injection, feedforward, bernoulli, procedure,...
# 29814  [retrieving, television, spectators, framework...
# ...                                                  ...
# 22317  [information, attribute, properties, previousl...
# 40848  [diagnosis, infection, preliminary, important,...
# 21676  [arbitrary, translates, naturally, histograms,...
# 22812  [arbitrary, functions, distributions, procedur...
# 3375   [redundant, irrelevant, instances, successful,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2768     [architectures, typically, cumbersome, automat...
# 25963    [techniques, improving, performance, animation...
# 28500    [detection, constrained, unconstrained, enviro...
# 21937    [injection, feedforward, bernoulli, procedure,...
# 29814    [retrieving, television, spectators, framework...
#                                ...
# 32241    [propagation, converges, stationary, strikingl...
# 7794     [architecture, randomized, rectified, architec...
# 3928     [algorithms, accurately, competent, landscape,...
# 4987     [techniques, automatically, designing, archite...
# 10546    [inference, observations, structure, generatin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8796 words.
# Out of those 4576 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be63af57-0cad-4fbf-9460-b7e87a2d62a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be63af57-0cad-4fbf-9460-b7e87a2d62a8")) {                    Plotly.newPlot(                        "be63af57-0cad-4fbf-9460-b7e87a2d62a8",                        [{"x":["annealing","requiring","competitive","surprisingly","convolutional","operators","performing","typically","efficient","architecture","procedure","morphisms","cumbersome","resources","optimization","architectures","magnitude","automatically","distribution","replacing","consistently","expression","principal","techniques","expressions","particular","explicitly","separately","variation","established","recognition","invariant","probabilistic","constrained","constructed","controlled","representations","individuals","animation","generalize","markerless","previously","normalize","difficult","available","sufficient","appearance","supervised","underlying","prediction","approaches","experiments","factorized","variations","different","improving","component","performance","procedures","disentangling","introduce","detection","environments","resolution","microphones","grayscale","unconstrained","occlusions","partially","background","researchers","essentially","illumination","occlusion","currently","literature","algorithm","parameters","converges","regularizing","incorporated","propagation","generalized","demonstrated","perturbations","relatively","feedforward","associated","injection","implemented","computationally","superiority","regularization","efficiency","establish","technique","penalization","empirical","perturbed","versatile","estimates","bernoulli","rehabilitation","connections","minimizing","demonstrates","objective","consistent","feasibility","conducted","retrieval","aggregation","framework","presented","intrusive","requirements","retrieving","television","maintained","definition","information","therefore","inappropriate","acceptance","agreement","widespread","extracted","observers","extraction","meaningful","multiscale","solutions","unlabeled","demonstrate","perceptual","applicability","inversion","availability","evaluation","strategies","experiment","constraints","processed","coherence","approximation","eigenvalue","essential","dictionaries","processing","challenges","conducting","furthermore","properties","disciplines","parameter","including","analyzing","independence","condition","constructing","dependency","dimensional","implement","important","variables","experimental","applications","appropriate","dependence","statistical","independent","independently","significantly","generation","reinforcement","according","algorithms","redundant","exploration","incorporate","proposals","referitgame","terminate","irrelevant","respectively","localizes","outperforms","referring","generated","description","exploiting","simultaneously","improvement","completion","intersections","determining","intersection","heuristic","effectiveness","directions"],"y":[7,40,142,32,409,47,87,115,429,240,127,2,3,61,327,133,51,166,221,13,37,57,40,421,45,275,71,33,69,42,363,72,152,67,50,35,230,45,5,61,2,86,5,166,338,68,84,187,102,237,429,601,11,78,749,89,115,883,36,6,348,358,85,106,3,7,24,21,56,77,78,21,33,30,57,123,814,282,31,9,22,67,75,88,12,70,15,114,2,106,104,44,85,160,44,267,1,140,4,6,67,6,1,49,50,59,175,83,29,90,124,34,515,169,2,45,11,2,8,36,685,148,8,9,22,24,124,8,136,53,9,160,39,559,25,39,4,23,266,88,63,145,23,19,109,3,78,18,303,116,5,173,184,12,126,264,48,26,47,43,39,182,75,355,136,390,444,100,28,152,115,37,273,147,125,115,590,18,53,49,31,2,3,10,94,7,273,9,186,82,78,123,132,37,5,25,15,60,199,39],"type":"bar"},{"x":["annealing","requiring","competitive","surprisingly","convolutional","operators"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4576,), (4576, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Multi</span> <span style=''>Scale</span> <span style=''>Cascade</span> <span style=''>Fully</span> <span style='background-color:rgba(0, 255, 0, 0.6592292089249492);'>Convolutional</span> <span style=''>Network</span> <span style=''>Face</span> <span style=''>Detector</span> <br/><br/><span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.5701754385964912);'>detection</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.44473007712082263);'>challenging</span> <span style=''>as</span> <span style=''>faces</span> <span style=''>in</span> <span style=''>images</span> <span style=''>could</span> <span style=''>be</span> <span style=''>present</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.40425531914893625);'>locations</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.30260869565217396);'>different</span> <span style=''>scales</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>three</span> <span style=''>stage</span> <span style=''>cascade</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>based</span> <span style=''>on</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6592292089249492);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(FCNs)</span> <span style=''>It</span> <span style=''>first</span> <span style=''>proposes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.40425531914893625);'>locations</span> <span style=''>where</span> <span style=''>the</span> <span style=''>faces</span> <span style=''>may</span> <span style=''>be</span> <span style=''>then</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>accurate</span> <span style=''>location</span> <span style=''>by</span> <span style=''>zooming</span> <span style=''>on</span> <span style=''>to</span> <span style=''>the</span> <span style=''>faces</span> <span style=''>Each</span> <span style=''>level</span> <span style=''>of</span> <span style=''>the</span> <span style=''>FCN</span> <span style=''>cascade</span> <span style=''>is</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>scale</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6592292089249492);'>convolutional</span> <span style=''>network</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.6629213483146067);'>generates</span> <span style=''>scores</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.30260869565217396);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.40425531914893625);'>locations</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.30260869565217396);'>different</span> <span style=''>scales</span> <span style=''>A</span> <span style=''>score</span> <span style=''>map</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>after</span> <span style=''>each</span> <span style=''>FCN</span> <span style=''>stage</span> <span style=''>Probable</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>face</span> <span style=''>are</span> <span style=''>selected</span> <span style=''>and</span> <span style=''>fed</span> <span style=''>to</span> <span style=''>the</span> <span style=''>next</span> <span style=''>stage</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.55);'>pr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorial</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Factorial</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>models</span> <span style=''>(FHMMs)</span> <span style=''>are</span> <span style=''>powerful</span> <span style=''>tools</span> <span style=''>of</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>Learning</span> <span style=''>FHMMs</span> <span style=''>yields</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneous</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>issue</span> <span style=''>ie</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>Markov</span> <span style=''>chains</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>each</span> <span style=''>chain</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>issue</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extending</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Bayesian</span> <span style=''>(FAB)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>to</span> <span style=''>FHMMs</span> <span style=''>First</span> <span style=''>we</span> <span style=''>offer</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>marginal</span> <span style=''>log</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>than</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>FAB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>Our</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style=''>out</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>yet</span> <span style=''>still</span> <span style=''>apply</span> <span style=''>the</span> <span style=''>Laplace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>emission</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>if</span> <span style=''>there</span> <span style=''>are</span> <span style=''>two</span> <span style=''>very</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>for</span> <span style=''>single</span> <span style=''>cell</span> <span style=''>RNA</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>sequencing</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>detecting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>genes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreting</span> <span style=''>gene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style=''>levels</span> <span style=''>that</span> <span style=''>are</span> <span style=''>observed</span> <span style=''>through</span> <span style=''>single</span> <span style=''>cell</span> <span style=''>RNA</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>sequencing</span> <span style=''>In</span> <span style=''>the</span> <span style=''>model</span> <span style=''>each</span> <span style=''>cell</span> <span style=''>has</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3476702508960574);'>dimensional</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.35304990757855825);'>representation</span> <span style='background-color:rgba(0, 255, 0, 0.30731707317073176);'>Additional</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3182957393483709);'>variables</span> <span style=''>account</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>technical</span> <span style=''>effects</span> <span style=''>that</span> <span style=''>may</span> <span style=''>erroneously</span> <span style=''>set</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.30973451327433627);'>observations</span> <span style=''>of</span> <span style=''>gene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style=''>levels</span> <span style=''>to</span> <span style=''>zero</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(255, 0, 0, 0.36182336182336183);'>distributions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>by</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>giving</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>enough</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>flexibility</span> <span style=''>to</span> <span style=''>fit</span> <span style=''>the</span> <span style=''>data</span> <span style=''>well</span> <span style=''>We</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.5529411764705882);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.321656050955414);'>inference</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.32211538461538464);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5504587155963303);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MARGIN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Uncovering</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>using</span> <span style=''>Graph</span> <span style=''>Signal</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretability</span> <span style=''>has</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>aspect</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>aimed</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>the</span> <span style=''>working</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>However</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>vary</span> <span style=''>vastly</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>task</span> <span style=''>with</span> <span style=''>each</span> <span style=''>use</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style=''>time</span> <span style=''>and</span> <span style=''>effort</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>MARGIN</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style=''>general</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>address</span> <span style=''>a</span> <span style=''>large</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>tasks</span> <span style=''>ranging</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prototypes</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explaining</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>MARGIN</span> <span style=''>exploits</span> <span style=''>ideas</span> <span style=''>rooted</span> <span style=''>in</span> <span style=''>graph</span> <span style=''>signal</span> <span style=''>analysis</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influential</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>those</span> <span style=''>nodes</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>function</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>carefully</span> <span style=''>defining</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>graphs</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07160940325497288)
# 	segmentation (0.0755877034358047)
# 	experimental (0.1410488245931284)
# 	knowledge (0.12477396021699819)
# 	processing (0.10958408679927667)
# 	information (0.24773960216998192)
# 	different (0.2708860759493671)
# 	detection (0.1294755877034358)
# 	recognition (0.13128390596745027)
# 	convolutional (0.14792043399638335)
#
# Some Statistics words are:
# 	convergence (0.11498771498771498)
# 	estimation (0.16265356265356265)
# 	stochastic (0.13513513513513514)
# 	statistical (0.14594594594594595)
# 	distribution (0.17641277641277642)
# 	algorithm (0.3936117936117936)
# 	theoretical (0.15135135135135136)
# 	dimensional (0.18476658476658478)
# 	regression (0.16756756756756758)
# 	inference (0.20393120393120392)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0f73f325-132e-46b2-832a-847ab1dc03f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f73f325-132e-46b2-832a-847ab1dc03f2")) {                    Plotly.newPlot(                        "0f73f325-132e-46b2-832a-847ab1dc03f2",                        [{"x":["annealing","requiring","competitive","surprisingly","convolutional","operators","performing","typically","efficient","architecture","procedure","morphisms","cumbersome","resources","optimization","architectures","magnitude","automatically","distribution","replacing","consistently","expression","principal","techniques","expressions","particular","explicitly","separately","variation","established","recognition","invariant","probabilistic","constrained","constructed","controlled","representations","individuals","animation","generalize","markerless","previously","normalize","difficult","available","sufficient","appearance","supervised","underlying","prediction","approaches","experiments","factorized","variations","different","improving","component","performance","procedures","disentangling","introduce","detection","environments","resolution","microphones","grayscale","unconstrained","occlusions","partially","background","researchers","essentially","illumination","occlusion","currently","literature","algorithm","parameters","converges","regularizing","incorporated","propagation","generalized","demonstrated","perturbations","relatively","feedforward","associated","injection","implemented","computationally","superiority","regularization","efficiency","establish","technique","penalization","empirical","perturbed","versatile","estimates","bernoulli","rehabilitation","connections","minimizing","demonstrates","objective","consistent","feasibility","conducted","retrieval","aggregation","framework","presented","intrusive","requirements","retrieving","television","maintained","definition","information","therefore","inappropriate","acceptance","agreement","widespread","extracted","observers","extraction","meaningful","multiscale","solutions","unlabeled","demonstrate","perceptual","applicability","inversion","availability","evaluation","strategies","experiment","constraints","processed","coherence","approximation","eigenvalue","essential","dictionaries","processing","challenges","conducting","furthermore","properties","disciplines","parameter","including","analyzing","independence","condition","constructing","dependency","dimensional","implement","important","variables","experimental","applications","appropriate","dependence","statistical","independent","independently","significantly","generation","reinforcement","according","algorithms","redundant","exploration","incorporate","proposals","referitgame","terminate","irrelevant","respectively","localizes","outperforms","referring","generated","description","exploiting","simultaneously","improvement","completion","intersections","determining","intersection","heuristic","effectiveness","directions","navigating","behaviors","shortcomings","autonomous","providing","instrumental","dynamical","difference","modification","processes","projection","comparison","computing","iteration","minimization","differences","geometric","extensive","complexity","stochastic","accelerated","alternating","direction","convergence","iterations","multipliers","acceleration","approximate","publications","variational","extensions","introduces","explained","arguments","posterior","analytical","inference","generally","correlated","overfitting","multiplicative","deterministic","regularisation","parametrisation","perspective","discussed","implications","implementation","diagnosis","angiography","correspondences","maximization","structures","developing","euclidean","fu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrisation
# 	degenerate
# 	mitigates
# 	thermodynamic
# 	zebrafish
# 	confounder
# 	dependences
# 	chemometrics
# 	methodologically
# 	elliptical
# 	advocated
# 	transelliptical
# 	horseshoe
# 	inhibited
# 	reparametrizations
# 	blockwise
# 	isometric
# 	distinguishability
# 	reversing
# 	constituents
# Some words which never appear in Statistics papers:
# 	animation
# 	markerless
# 	microphones
# 	grayscale
# 	occlusions
# 	illumination
# 	intrusive
# 	television
# 	observers
# 	referitgame
# 	referring
# 	navigating
# 	angiography
# 	consultation
# 	prisoners
# 	reflection
# 	visuomotor
# 	velocities
# 	pipelined
# 	argumentation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.103084465959164e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
